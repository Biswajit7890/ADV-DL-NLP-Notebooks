# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import json
from pathlib import Path

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-96aca52d-4606-4560-b94c-e044531fc2ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96aca52d-4606-4560-b94c-e044531fc2ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train_bangla_samples_fixed_preprocessed.json to train_bangla_samples_fixed_preprocessed.json
# Saving valid_bangla_samples_fixed_preprocessed.json to valid_bangla_samples_fixed_preprocessed.json

# %%
import json
from pathlib import Path

def read_squad(path):
    path = Path(path)
    with open(path, 'rb') as f:
        squad_dict = json.load(f)

    contexts = []
    questions = []
    answers = []
    for group in squad_dict['data']:
        for passage in group['paragraphs']:
            context = passage['context']
            for qa in passage['qas']:
                question = qa['question']
                for answer in qa['answers']:
                    contexts.append(context)
                    questions.append(question)
                    answers.append(answer)
    return contexts, questions, answers

# %%
train_contexts, train_questions, train_answers = read_squad('/content/train_bangla_samples_fixed_preprocessed.json')
val_contexts, val_questions, val_answers = read_squad('/content/valid_bangla_samples_fixed_preprocessed.json')

# %%
train_answers[50]
# Out:
# {'answer_start': 1014, 'text': ' শহরগুলি এ'}

# %%
def add_end_idx(answers, contexts):
    for answer, context in zip(answers, contexts):
        gold_text = answer['text']
        start_idx = answer['answer_start']
        end_idx = start_idx + len(gold_text)

       
        if context[start_idx:end_idx] == gold_text:
            answer['answer_end'] = end_idx
        elif context[start_idx-1:end_idx-1] == gold_text:
            answer['answer_start'] = start_idx - 1
            answer['answer_end'] = end_idx - 1   
        elif context[start_idx-2:end_idx-2] == gold_text:
            answer['answer_start'] = start_idx - 2
            answer['answer_end'] = end_idx - 2

# %%
add_end_idx(train_answers, train_contexts)
add_end_idx(val_answers, val_contexts)

# %%
from transformers import AutoTokenizer
import torch
tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-uncased")

# %%
train_encodings = tokenizer(train_contexts, train_questions, truncation=True, padding=True,return_tensors='pt',max_length=50)
val_encodings = tokenizer(val_contexts, val_questions, truncation=True, padding=True,return_tensors='pt',max_length=50)

# %%
def add_token_positions(encodings, answers):
    start_positions = []
    end_positions = []
    for i in range(len(answers)):
        start_positions.append(encodings.char_to_token(i, answers[i]['answer_start']))
        end_positions.append(encodings.char_to_token(i, answers[i]['answer_end']))

        # if start position is None, the answer passage has been truncated
        if start_positions[-1] is None:
            start_positions[-1] = tokenizer.model_max_length
        if end_positions[-1] is None:
            end_positions[-1] = tokenizer.model_max_length

    encodings.update({'start_positions': start_positions, 'end_positions': end_positions})

# %%
add_token_positions(train_encodings, train_answers)
add_token_positions(val_encodings, val_answers)

# %%
train_encodings.keys()
# Out:
# dict_keys(['input_ids', 'attention_mask'])

# %%
class SquadDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)

# %%
train_dataset = SquadDataset(train_encodings)
val_dataset = SquadDataset(val_encodings)

# %%
from transformers import  BertForQuestionAnswering
model = BertForQuestionAnswering.from_pretrained('bert-base-multilingual-uncased',return_dict=True,output_attentions=True)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader
from transformers import AdamW
from tqdm import tqdm

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

model.to(device)
model.train()

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

optim = AdamW(model.parameters(), lr=5e-5)

for epoch in range(1):
    model.train()
    loop = tqdm(train_loader, leave=True)
    for batch in loop:
        optim.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        start_positions = batch['start_positions'].to(device)
        end_positions = batch['end_positions'].to(device)
        outputs = model(input_ids, attention_mask=attention_mask, start_positions=start_positions, end_positions=end_positions)
        loss = outputs[0]
        loss.backward()
        optim.step()
        loop.set_description(f'Epoch {epoch}')
        loop.set_postfix(loss=loss.item())
# Out:
#   0%|          | 0/2121 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# Epoch 0: 100%|██████████| 2121/2121 [04:20<00:00,  8.13it/s, loss=1.38]

# %%
model_path='/content/models'
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('/content/models/tokenizer_config.json',
#  '/content/models/special_tokens_map.json',
#  '/content/models/vocab.txt',
#  '/content/models/added_tokens.json')

# %%
model_path = '/content/models'
model = BertForQuestionAnswering.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)

# %%
model = model.to(device)
model.eval()
val_loader = DataLoader(val_dataset, batch_size=16)
acc = []
for batch in val_loader:
    with torch.no_grad():
         input_ids = batch['input_ids'].to(device)
         attention_mask = batch['attention_mask'].to(device)
         start_true = batch['start_positions'].to(device)
         end_true = batch['end_positions'].to(device)
         outputs = model(input_ids, attention_mask=attention_mask)
         start_pred = torch.argmax(outputs['start_logits'], dim=1)
         end_pred = torch.argmax(outputs['end_logits'], dim=1)
         acc.append(((start_pred == start_true).sum()/len(start_pred)).item())
         acc.append(((end_pred == end_true).sum()/len(end_pred)).item())
acc = sum(acc)/len(acc)
print(acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 0.07952724358974358

# %%
for contxt,quas in zip(val_contexts,val_questions):
    val_encodings=tokenizer(contxt, quas, truncation=True, padding=True)
    with torch.no_grad():
         outputs = model(input_ids, attention_mask=attention_mask)
         start_pred = torch.argmax(outputs['start_logits'], dim=1)
         end_pred = torch.argmax(outputs['end_logits'], dim=1)
         all_tokens = tokenizer.convert_ids_to_tokens(val_encodings["input_ids"])
         answer = ' '.join(all_tokens[start_pred[0]:end_pred[0]])
         print("The qusetion is :",quas)
         print("The answer is :",answer)
         print('*'*50)
# Out:
# The qusetion is : চার্লসটন, দক্ষিণ ক্যারোলিনা কোন কাউন্টিতে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন কোন বন্দরে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন হারবার কোন মহাসাগরের খাঁড়ি?
# The answer is :
# **************************************************
# The qusetion is : কোপার নদীর সাথে কোন নদী মিশে গিয়ে চার্লস্টন হারবার গঠন করে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন কোন কাউন্টিতে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন হারবার কোন সমুদ্রের উপর গঠিত?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন হারবার থেকে অ্যাশলে নদীর সাথে কোন নদী মিশে গেছে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন কোন সালে প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের আসল নাম কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউনটির নামকরণ করা হয়েছিল কোন রাজার নামে?
# The answer is :
# **************************************************
# The qusetion is : শহরটি মূলত কোথায় ছিল?
# The answer is :
# **************************************************
# The qusetion is : ২০১০ সালে চার্লস্টনের জনসংখ্যা কত ছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন মূলত কোন বছর প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের মূল নাম কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউন কে নামকরণ করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ২০১০ সালে চার্লস্টনে কত লোক বাস করত?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের প্রথম অবস্থানটি কোথায় ছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন, দক্ষিণ ক্যারোলিনা কত বড়?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন উপদ্বীপ প্রসারিত করার জন্য কোন শহরটি অবরুদ্ধ করে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের কত অংশ জল দ্বারা isাকা?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের মোট অঞ্চল শুকনো জমি কেমন?
# The answer is :
# **************************************************
# The qusetion is : কোন শহর কুপার নদীর সরাসরি পূর্ব দিকে জমি দখল করে?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের সবচেয়ে মরসুমে কোন মৌসুম?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের বার্ষিক বৃষ্টিপাতের অর্ধেকটি কোন আকারে ঘটে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের সংক্ষিপ্ত রূপটি কোন মৌসুমে চিহ্নিত করা হয়?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের তুষারপাতের মৌসুমী রেকর্ডটি কী?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনে কোন মরসুমকে সংক্ষিপ্ত বিবেচনা করা হয়?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের সবচেয়ে আর্দ্র মৌসুমটি কী?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের বার্ষিক বৃষ্টিপাতের অর্ধেকটি কোন আকারে ঘটে?
# The answer is :
# **************************************************
# The qusetion is : ১৯৮৯ সালের ২৩ শে ডিসেম্বর চার্লস্টনের বিমানবন্দর কতটা তুষারপাত করেছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লটসনের নগর সীমাতে সবচেয়ে উত্তপ্ত তাপমাত্রা রেকর্ড করা কী?
# The answer is :
# **************************************************
# The qusetion is : গ্রীষ্মে এবং শুরুর দিকে শরলটসনের জন্য কোন ধরণের ঝড় একটি বড় হুমকি?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনে 1989 সালে কোন হারিকেন আঘাত হানে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের শহরের সীমাটি রেকর্ড করা সর্বনিম্ন তাপমাত্রা কোনটি?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের বিমানবন্দর কোন দিন রেকর্ডের সবচেয়ে শীততম দিনে আঘাত করেছিল?
# The answer is :
# **************************************************
# The qusetion is : ২০১০ সালে চার্লস্টন = উত্তর চার্লসটন আরবান এরিয়াতে কত লোক বাস করত?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনার তৃতীয় বৃহত্তম শহর কোনটি?
# The answer is :
# **************************************************
# The qusetion is : 2000 সালে কতগুলি লোক মনস কর্নারে বাস করত?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন এবং বার্কলে অন্য কোন কাউন্টির সাথে মিলিত হয়ে একটি মহানগর পরিসংখ্যান অঞ্চল গঠন করে?
# The answer is :
# **************************************************
# The qusetion is : মন্টস কর্নার কোন কাউন্টিতে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : কোন যুগে দক্ষিণ ক্যারোলিনায় কাউন্টি নিয়ে এসেছিল?
# The answer is :
# **************************************************
# The qusetion is : কাউন্টি দক্ষিণ ক্যারোলাইনা কোন সিস্টেম প্রতিস্থাপন?
# The answer is :
# **************************************************
# The qusetion is : আজকাল প্যারিশ সিস্টেমের প্রধান ব্যবহার কী?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন শহরটি সেন্ট মাইকেলের প্যারিশের সীমা দ্বারা সংজ্ঞায়িত করা হয়েছে এবং অন্য কোন পারিশ?
# The answer is :
# **************************************************
# The qusetion is : সেন্ট জন প্যারিশ ছাড়া অন্য কোন প্যারিশ বেশিরভাগই একসাথে গ্রামীণ প্যারিশ?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউন কোন সালে প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ক্যারোলিনা প্রদেশের বন্দোবস্ত অভিযান প্রতিষ্ঠা করতে কতক্ষণ সময় লাগল?
# The answer is :
# **************************************************
# The qusetion is : ক্যারোলিনা প্রদেশটি স্থাপন ও উন্নয়নের পরিকল্পনা কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : "গ্র্যান্ড মডেল" নামে পরিচিত পরিকল্পনাটি কে প্রস্তুত করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের আসল বসতি কোথা থেকে এসেছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের প্রথম গভর্নর কে?
# The answer is :
# **************************************************
# The qusetion is : কে ভবিষ্যদ্বাণী করেছিলেন চার্লসটন 'গ্রেট বন্দর শহরে' পরিণত হবে?
# The answer is :
# **************************************************
# The qusetion is : বন্দোবস্তটি পূর্বে কোন নদীতে স্থানান্তরিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন ধর্মীয় দলকে দক্ষিণ ক্যারোলিনায় বসতি স্থাপনের অনুমতি ছিল না?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন আমেরিকাতে সবচেয়ে ধনী ইহুদি সম্প্রদায়টি বন্ধ করে দেওয়া কোন বছর সম্পর্কে?
# The answer is :
# **************************************************
# The qusetion is : প্রথম চার্লস্টন বসতি স্থাপনকারীদের মধ্যে অনেকে ইউরোপীয় কোন দেশ থেকে এসেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : কোন যুদ্ধের পরে রাষ্ট্র ক্যাথলিকদের উপর নিষেধাজ্ঞার অবসান ঘটিয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : বারমুডার পাশাপাশি আরও কতগুলি ইংরেজী উপনিবেশ এসেছিল?
# The answer is :
# **************************************************
# The qusetion is : ফ্রান্সের সাথে কোন দেশ চার্লসটন অঞ্চলে ইংল্যান্ডের দাবিতে প্রতিদ্বন্দ্বিতা করেছিল?
# The answer is :
# **************************************************
# The qusetion is : জনগোষ্ঠী থেকে নিজেকে রক্ষার উপায় হিসাবে কোন গোষ্ঠী বন্দোবস্তে অভিযান চালায়?
# The answer is :
# **************************************************
# The qusetion is : শহরটির সুরক্ষার জন্য কার 1704 পরিকল্পনা ব্যবহার করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : দুর্গে প্রাচীরের সিংহভাগ সরিয়ে দেওয়া হয়েছিল কোন দশকে?
# The answer is :
# **************************************************
# The qusetion is : ইউরোপীয় দেশ এবং আদি আমেরিকানদের পাশাপাশি চার্লসটন বন্দোবস্তে আর কে আক্রমণ করেছিল?
# The answer is :
# **************************************************
# The qusetion is : সুলিভান দ্বীপে সাধারণ বেঞ্চের জন্য কোন লেখক মূল্য দিয়েছেন?
# The answer is :
# **************************************************
# The qusetion is : উত্তর আমেরিকার দাস হিসাবে বিক্রি হওয়া শতকরা কত ভাগ সুলিভান দ্বীপে অবতরণ করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : দাস ব্যবসায়ের কোন পর্যায়ে চার্লস টাউনকে দাস সরবরাহ করেছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন মানুষকে চার্লস টাউনে দাস হতে আনা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : আফ্রিকান ক্রীতদাসদের কোন পণ্যটির চাষ সম্পর্কে দুর্দান্ত জ্ঞান ছিল?
# The answer is :
# **************************************************
# The qusetion is : নিম্ন দেশ থেকে কোন দেশ নীল ফসলকে ভর্তুকি দেয়?
# The answer is :
# **************************************************
# The qusetion is : নীচের দেশটির জন্য নীল একটি শীর্ষস্থানীয় রফতানি হয়েছিল কোন বছর?
# The answer is :
# **************************************************
# The qusetion is : কোন বছরের মধ্যে ধানটি নিম্ন-জমি জন্য একটি সফল পণ্য ফসল ছিল?
# The answer is :
# **************************************************
# The qusetion is : লোকাউন্ট্রি থেকে নীলার সাথে কী পণ্য রফতানি করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউন বৃদ্ধিতে কোন লাভজনক বাণিজ্য ব্যাপক অবদান রেখেছিল?
# The answer is :
# **************************************************
# The qusetion is : আফ্রিকান বংশোদ্ভূত মানুষ কোন গণআন্দোলন অবধি চার্লসনে সংখ্যাগরিষ্ঠ ছিল?
# The answer is :
# **************************************************
# The qusetion is : 1739 থেকে 1761 পর্যন্ত চার্লস টাউনে হরিণ জবাইয়ের অনুমান কী?
# The answer is :
# **************************************************
# The qusetion is : রেকর্ডগুলি ইঙ্গিত দেয় যে হরিণ ব্যবসায়ের উচ্চতার সময় চার্লস টাউন থেকে কত পাউন্ড হরিণের স্কিনগুলি রফতানি করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউন এর মূল অর্থনীতির ভিত্তি কোন বাণিজ্য ছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউন 1699 থেকে 1715 এর মধ্যে ইউরোপে যে হরিণের চামড়া রফতানি করেছিল তার গড় পরিমাণ কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনার প্রাচীনতম কলেজটি কী?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন কোন বছর অবধি চার্লস টাউন কলেজ সমর্থন করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউন লাইব্রেরি সোসাইটি কোন সালে প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস টাউনের প্রথম থিয়েটার ভবনটি যেখানে দাঁড়িয়েছিল তা কোথায় অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : আমেরিকা বিপ্লবের সময় কোন জেনারেল চার্লস টাউন দখলের চেষ্টা করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : জেনারেল ক্লিনটন কখন দক্ষিণ ক্যারোলিনা আক্রমণ করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনা রক্ষায় আমেরিকান বাহিনীর কমান্ডার কে ছিলেন?
# The answer is :
# **************************************************
# The qusetion is : যুদ্ধের পরে ফোর্ট সুলিভানের নামকরণ করা হয় কি?
# The answer is :
# **************************************************
# The qusetion is : আমেরিকান বিপ্লবের বৃহত্তম আমেরিকান পরাজয় কি ছিল?
# The answer is :
# **************************************************
# The qusetion is : জেনারেল ক্লিনটন কত সৈন্য নিয়ে ফিরে এসেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : কোন বছরে জেনারেল ক্লিনটন চার্লস টাউনে ফিরে এসেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : জেনারেল লিংকন কত সৈন্য নেতৃত্বে ছিলেন?
# The answer is :
# **************************************************
# The qusetion is : কোন শহর দক্ষিণ ক্যারোলিনা রাজ্যের রাজধানী হয়ে ওঠে?
# The answer is :
# **************************************************
# The qusetion is : 1860 সালে চার্লস্টনে কত রঙের মুক্ত মানুষ বাস করতেন?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের জনসংখ্যার কত শতাংশ রঙ মুক্ত মানুষ ছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের কালো জনসংখ্যার কত শতাংশ রঙের মুক্ত মানুষ ছিল?
# The answer is :
# **************************************************
# The qusetion is : ব্রাউন ফেলোশিপ সোসাইটি কোন সালে প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ব্রাউন ফেলোশিপ সোসাইটি কোন সালে শেষ হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ডেনমার্ক ভেসি কী পরিকল্পনা করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : দাস বিদ্রোহের জন্য ভেসির পরিকল্পনা কখন প্রকাশিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ভাসির সাথে কত দাসকে মৃত্যুদন্ড কার্যকর করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন বিপ্লব শ্বেতীদের দাসের প্রতিশোধের ভয়ে ভীত করে তুলেছিল?
# The answer is :
# **************************************************
# The qusetion is : 1860 সালে চার্লস্টনে কত আফ্রিকান আমেরিকান বাস করতেন?
# The answer is :
# **************************************************
# The qusetion is : 1880 সালে চার্লস্টনে কত আফ্রিকান আমেরিকান বাস করতেন?
# The answer is :
# **************************************************
# The qusetion is : এএমই জিয়ন চার্চগুলি আমেরিকার কোন অংশে প্রথম প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কুকুর এবং বন্দুক সহ কী কী নিষিদ্ধ পণ্য ছিল, দাসত্বের অবসান ঘটার পরে ফ্রিম্যানরা কী চায়?
# The answer is :
# **************************************************
# The qusetion is : অ্যাভেরি নরমাল ইনস্টিটিউট প্রতিষ্ঠা করে কোন সংস্থা?
# The answer is :
# **************************************************
# The qusetion is : অ্যাভারি নরমাল ইনস্টিটিউট কোন ধরণের স্কুল ছিল?
# The answer is :
# **************************************************
# The qusetion is : কে অ্যাভেরি নরমাল ইনস্টিটিউটে পড়েছেন?
# The answer is :
# **************************************************
# The qusetion is : কোন সাধারণ মার্কিন আর্সেনালের পোর্টার মিলিটারি একাডেমিতে রূপান্তরকে সমর্থন করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : পোর্টার মিলিটারি একাডেমির সহায়তায় সৈনিক এবং ছেলেরা কী দ্বারা প্রভাবিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ১৮75৫ সালে চার্লস্টনের জনসংখ্যার কত শতাংশ কালো ছিল?
# The answer is :
# **************************************************
# The qusetion is : 1875 সালে চার্লসটন কাউন্টি কত শতাংশ কালো ছিল?
# The answer is :
# **************************************************
# The qusetion is : 1876 সালে, চার্লসটনের ব্ল্যাক রিপাবলিকানরা কার বিরুদ্ধে লড়াই করেছিল?
# The answer is :
# **************************************************
# The qusetion is : 1876 এর দ্বিতীয় দাঙ্গাটি কখন হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ১৮7676 সালে চার্লস্টনে কালো এবং সাদাদের মধ্যে কতগুলি বড় দাঙ্গা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনে সাদা ডেমোক্রেটিক আধা-সামরিক দলগুলি কী নামে পরিচিত?
# The answer is :
# **************************************************
# The qusetion is : আমেরিকান নাগরিকত্ব কী ছিল ফ্রিম্যানকে?
# The answer is :
# **************************************************
# The qusetion is : কিংসের রাস্তায় সংঘটিত 1876 সালের ঘটনাটি কোন দিন ঘটেছিল?
# The answer is :
# **************************************************
# The qusetion is : ভোটারদের ভয় দেখানোর ফলে 1876 সালের নির্বাচনে কে জিতল?
# The answer is :
# **************************************************
# The qusetion is : 1886 সালে চার্লস্টনের প্রায় ধ্বংস কি?
# The answer is :
# **************************************************
# The qusetion is : 1886 সালের চার্লস্টন ভূমিকম্পের তারিখটি কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনে 1886 সালের ভূমিকম্পে কতটি বিল্ডিং ক্ষতিগ্রস্থ হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টন শহরে 1886 সালের ভূমিকম্পের ক্ষয়ক্ষতির দাম কত?
# The answer is :
# **************************************************
# The qusetion is : ভূমিকম্পের আগে চার্লসটনের সমস্ত শহরের বিল্ডিংয়ের মোট মূল্য কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : নতুন সংবিধান কোন বছর কেটে গিয়েছিল যে কৃষ্ণাঙ্গদের সাথে বৈষম্যমূলক আচরণ করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : উইলিয়াম এনস্টন হোম কোন সালে নির্মিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনায় কৃষ্ণাঙ্গরা কি সংখ্যাগরিষ্ঠ ছিল?
# The answer is :
# **************************************************
# The qusetion is : একটি বড় ডাকঘর এবং আদালতটি কোন সালে নির্মিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনার চার্লস্টনে নয় জন গির্জার সদস্যকে হত্যা করে 21 বছরের বৃদ্ধের নাম কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : ক্লিমেন্টা পিনকনি দক্ষিণ ক্যারোলিনা রাজ্যের জন্য কোন সরকারী অফিসে কাজ করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনা স্টেট হাউস থেকে কনফেডারেটের পতাকাটি কোন দিন সরানো হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : নয়টি ভুক্তভোগীদের জন্য একটি স্মারক পরিষেবাটি কোন কলেজের ক্যাম্পাসে অনুষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : স্পোলিটো ফেস্টিভাল ইউএসএ কোন মৌসুমে অনুষ্ঠিত হয়?
# The answer is :
# **************************************************
# The qusetion is : স্পোলিটো ফেস্টিভাল ইউএসএ কোন সালে প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : জিয়ান কার্লো মেনোটির পেশা কী?
# The answer is :
# **************************************************
# The qusetion is : স্পোলিটো ফেস্টিভাল ইউএসএ কোন ইতালিয়ান উত্সবের প্রতিপক্ষ?
# The answer is :
# **************************************************
# The qusetion is : জিয়ান কার্লো মেনোটি কোন বড় পুরষ্কার জিতেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : ফুটলাইট খেলোয়াড়রা কোন সালে নাট্য প্রযোজনা তৈরি শুরু করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : বার্ষিক চার্লসটন ফ্যাশন সপ্তাহ কোথায় অনুষ্ঠিত হয়?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টন রন্ধনপ্রণালী কোন দুটি সংস্কৃতি দ্বারা প্রভাবিত হয়?
# The answer is :
# **************************************************
# The qusetion is : "চার্লস্টনের প্রাদেশিকতা" প্রকাশিত হয় কোন সালে?
# The answer is :
# **************************************************
# The qusetion is : "দ্য হুগেনোট এলিমেন্ট ইন চার্লস্টনের প্রাদেশিকতা" শীর্ষক রচনাটির রচয়িতা কে?
# The answer is :
# **************************************************
# The qusetion is : সিলভেস্টার প্রাইমার কোন কলেজের অন্তর্ভুক্ত?
# The answer is :
# **************************************************
# The qusetion is : কোন দুটি প্রাথমিক সংস্কৃতি চার্লসনের উচ্চারণের অনন্য বৈশিষ্ট্যযুক্ত?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের উচ্চারণে প্রাইমারের কাজটি কোন ধরণের জার্নাল প্রকাশিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : প্রতি বছর স্পোলিটো ফেস্টিভাল ইউএসএ কত দিন চালায়?
# The answer is :
# **************************************************
# The qusetion is : স্পোলিটো ফেস্টিভ্যাল ইউএসএ কোন ধরণের উত্সব?
# The answer is :
# **************************************************
# The qusetion is : লাইটের হলিডে ফেস্টিভাল কোথায় অনুষ্ঠিত হয়?
# The answer is :
# **************************************************
# The qusetion is : "চার্লসটন" কে লিখেছেন?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টন নৃত্যটি কোন দশকে জাতীয়ভাবে জনপ্রিয় ছিল?
# The answer is :
# **************************************************
# The qusetion is : "চার্লস্টন রাগ" গানটি কে তৈরি করেছেন?
# The answer is :
# **************************************************
# The qusetion is : কোন চার্লসটন সম্প্রদায়ের জাজ সংগীতে বিশাল প্রভাব ছিল?
# The answer is :
# **************************************************
# The qusetion is : গিচি নৃত্যের সাথে কি ধরণের শ্রমিকের সংগীত জড়িত?
# The answer is :
# **************************************************
# The qusetion is : জেনকিনস এতিমখানাটি কোন বছর তৈরি হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন রেভারেন্ড জেনকিনস এতিমখানা প্রতিষ্ঠা করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : জারকিনস এতিমখানা কী ধরণের অনুদান গ্রহণ করেছিল?
# The answer is :
# **************************************************
# The qusetion is : কার স্নাতকদের জেনকিনস এতিমখানা থেকে অনেক ছেলেকে প্রশিক্ষণ দেওয়া হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : লুই আর্মস্ট্রং কোন শহর থেকে এসেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : জেন্টিনস এতিমখানা টাফট ছাড়া অন্য কোন রাষ্ট্রপতি খেলেন?
# The answer is :
# **************************************************
# The qusetion is : ব্রডওয়েতে জেনকিনস অরফানেজ ব্যান্ডটি কোন খেলার জন্য খেলল?
# The answer is :
# **************************************************
# The qusetion is : 'পর্গি' অবলম্বনে "ফোকা অপেরা" নামটি কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : গার্সউইন এবং হায়ওয়ার্ড কোথায় তাদের লোক অপেরা লিখেছেন?
# The answer is :
# **************************************************
# The qusetion is : গার্সউইন এবং হায়ওয়ার্ড কবে তাদের লোক অপেরা রচনা করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টন ফায়ার ডিপার্টমেন্টে কতটি সংস্থা রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের কাছে কয়টি ফুলটাইম ফায়ার ফাইটার রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : ২০০৮ সালের জুন পর্যন্ত ফায়ার চিফ কে ছিলেন?
# The answer is :
# **************************************************
# The qusetion is : ২০০৮ সালের নভেম্বর মাসে কে ফায়ার চিফ হন?
# The answer is :
# **************************************************
# The qusetion is : দমকল বিভাগের কত টাওয়ার সংস্থা রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনার বৃহত্তম পুলিশ বিভাগ কী?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টন পুলিশ বিভাগে কত রিজার্ভ পুলিশ অফিসার রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন পুলিশ বিভাগে কতজন বেসামরিক লোক কাজ করে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন পুলিশ বিভাগের বর্তমান প্রধান কে?
# The answer is :
# **************************************************
# The qusetion is : রূবেন গ্রিনবার্গ কোন বছরে চার্লসটন পুলিশ বিভাগের প্রধান হিসাবে অবসর গ্রহণ করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : পূর্ব কুপার আঞ্চলিক মেডিকেল সেন্টার কোথায়?
# The answer is :
# **************************************************
# The qusetion is : ট্রিডেন্ট আঞ্চলিক মেডিকেল সেন্টারটি কোথায় অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : বন সিকোর্স-সেন্ট ফ্রান্সিস জাভিয়ার হাসপাতাল শহরের কোন অংশে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : বায়োটেকনোলজি এবং চিকিত্সা গবেষণা ক্ষেত্রে কোন মেডিকেল জেলা বৃদ্ধি পাচ্ছে?
# The answer is :
# **************************************************
# The qusetion is : কোন বিমানবন্দরটি চার্লসটনে সিটিকে পরিষেবা সরবরাহ করে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন আন্তর্জাতিক বিমানবন্দরটি কোন শহরে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : শহরতলির চার্লস্টন থেকে বিমানবন্দর কতটা দূরে?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টন এক্সিকিউটিভ বিমানবন্দরটি কোথায় অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : বিমানবন্দরের নিকটে কোন মিলিটারি বেস রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের কোন অঞ্চলটিকে 'শিল্প অঞ্চল' হিসাবে বিবেচনা করা হয়?
# The answer is :
# **************************************************
# The qusetion is : চার্লসনের শহরতলিতে কিং স্ট্রিট কোন হাইওয়ে?
# The answer is :
# **************************************************
# The qusetion is : মার্কিন যুক্তরাষ্ট্রের হাইওয়ে 78 কোন রাস্তার সাথে একীভূত হয়েছে?
# The answer is :
# **************************************************
# The qusetion is : ইন্টারস্টেট 526 শুরু হয় এবং কোন হাইওয়েতে শেষ হয়?
# The answer is :
# **************************************************
# The qusetion is : ইন্টারস্টেট 26 শুরু হয় চার্লস্টনের কোন অংশে?
# The answer is :
# **************************************************
# The qusetion is : আর্থার রাভেনেল জুনিয়র ব্রিজটি কোন বছর খোলা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : গ্রেস মেমোরিয়াল সেতুটি কোন বছর নির্মিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : সিলাস এন পিয়ারম্যান সেতুটি কোন সালে নির্মিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : আর্থার রাভেনেল জুনিয়র ব্রিজটি কোন নদী পেরিয়েছে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের প্রাচীনতম কিছু বেসরকারী স্কুল কত দিন শেষ হয়েছে?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের রোমান ক্যাথলিক ডায়োসিস কোন ধরণের স্কুল তদারকি করেন?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের কয়েকটি বেসরকারী বিদ্যালয়ের বয়স কত?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনের ডায়োসেসন হাই স্কুল কোন স্কুল?
# The answer is :
# **************************************************
# The qusetion is : কোন সংস্থা বেশ কয়েকটি কে -8 পেরোকিয়াল স্কুল তদারকি করে?
# The answer is :
# **************************************************
# The qusetion is : বিশপ ইংল্যান্ড হাই স্কুল, পোর্টার-গাউড স্কুল এবং চার্লসটনের সর্বাধিক বিশিষ্ট বেসরকারী স্কুলগুলির মধ্যে অন্য কোন স্কুলটি রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : দেশের ১৩ তমতম বিশ্ববিদ্যালয়টি কী?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের আর্ট ইনস্টিটিউটটি কোথায় অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের আর্ট ইনস্টিটিউটটি কোন বছর খোলা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটন কলেজ বিল্ডিং আর্টস ডিগ্রি প্রদান করে?
# The answer is :
# **************************************************
# The qusetion is : শহরতলির চার্লস্টনে কোন টেকনিক্যাল কলেজের ক্যাম্পাস রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টনের বোন শহরের নাম কী?
# The answer is :
# **************************************************
# The qusetion is : স্পোলিটো কোন দেশে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : আমেরিকাতে কোন উত্সবের হোস্টিংয়ের জন্য চার্লসটন কে নির্বাচন করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : স্পোলিটোতে উত্সবটির নাম কী?
# The answer is :
# **************************************************
# The qusetion is : জিয়ান কার্লো মেনোটির পেশা কী?
# The answer is :
# **************************************************
# The qusetion is : পোলারিস মিসাইল সুবিধা আটলান্টিক স্টেশনটি কোন বছর বন্ধ ছিল?
# The answer is :
# **************************************************
# The qusetion is : পোলারিস মিসাইল সুবিধা আটলান্টিক স্টেশনে কয়টি পারমাণবিক ওয়ারহেড সংরক্ষণ করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : অস্ত্র স্টেশনগুলিতে কয়টি এসএসবিএন "বুমার" স্কোয়াড্রন হোমপোর্ট করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : সাবমেরিন স্কোয়াড্রন 4 কোন ধরনের সামরিক ঘাঁটিতে হোমপোর্ট করা হয়?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনা কোন বছরে তাদের একটি ফেডারেল আইন বাতিল করার অনুমতি দিয়ে একটি আইন পাস করেছিল?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনা বাতিল করার একটি অধ্যাদেশ পাস করার পরে, কে চার্লস্টনের দুর্গে পাঠানো হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : দক্ষিণ ক্যারোলিনা বাতিল করার একটি অধ্যাদেশ পাস করার পরে, কে চার্লসটন হারবারকে প্রেরণ করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : 1832 সালে চার্লসটনে সৈন্য প্রেরণের ফেডারেল অ্যাকশনটি কী নামে পরিচিত?
# The answer is :
# **************************************************
# The qusetion is : চার্লস্টন বন্দরে কি শিল্প নির্ভর?
# The answer is :
# **************************************************
# The qusetion is : 1840 সালে চার্লস্টনে প্রতিদিন তাজা খাবার বিক্রি হত কোথায়?
# The answer is :
# **************************************************
# The qusetion is : কোন বছরে দাসদের আইনী আমদানি শেষ হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : যে অঞ্চলে তুলার আবাদ করা হয়েছিল সে অঞ্চলটি কী নামে পরিচিত?
# The answer is :
# **************************************************
# The qusetion is : কোন যুগে দশ লক্ষ দাস পুরো দক্ষিণ জুড়ে বাণিজ্য পেয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : 1868 থেকে 1876 পর্যন্ত নির্বাচিতদের শতকরা কত ভাগ ছিল ফ্রিম্যান?
# The answer is :
# **************************************************
# The qusetion is : চার্লসনে ফ্রিম্যান কোন দলের নেতা হয়েছিলেন?
# The answer is :
# **************************************************
# The qusetion is : মুক্ত দাসেরা বৈষম্যের পাশাপাশি যুদ্ধোত্তর চার্লসটনে আর কীসের মুখোমুখি হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : চার্লসটনে ফেডারেল বাহিনী কীসের জন্য রইল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ কোন মহাসাগরে পাওয়া যায়?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের নিকটতম জমি ভর কত দূরে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে কত লোক বাস করেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ থেকে ইভান্স হেড কত দূরে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ কে উপনিবেশ করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ 1788 সাল থেকে 1855 পর্যন্ত বেশিরভাগ সময় কী উদ্দেশ্যে কাজ করেছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে নাগরিকরা স্থায়ীভাবে বসবাস শুরু করার কোন তারিখ শুরু করেছিল?
# The answer is :
# **************************************************
# The qusetion is : 1856 সালে নরফোক দ্বীপের প্রথম স্থায়ী বেসামরিক লোকেরা কোথায় বসতি স্থাপন করেছিল?
# The answer is :
# **************************************************
# The qusetion is : যুক্তরাজ্য কোন বছরে নরফোক দ্বীপটিকে অস্ট্রেলিয়ার প্রশাসনের জন্য হস্তান্তর করেছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন বছর ব্রিটিশ সরকার নরফোক দ্বীপকে সহায়ক বন্দোবস্ত হিসাবে অন্তর্ভুক্ত করেছিল?
# The answer is :
# **************************************************
# The qusetion is : 1786 সালে নরফোক দ্বীপটিকে ব্রিটিশ সহায়ক বন্দোবস্ত হিসাবে অন্তর্ভুক্ত করার ধারণাটি কে প্রস্তাব করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : সহায়ক নিষ্পত্তি হিসাবে নরফোক দ্বীপকে অন্তর্ভুক্ত করার সাথে সাথে, ব্রিটিশ সরকার কোন whatপনিবেশ স্থাপনের পরিকল্পনা করেছিল অস্ট্রেলিয়া রাজ্য?
# The answer is :
# **************************************************
# The qusetion is : ব্রিটিশরা নরফোক দ্বীপ নিষ্পত্তি করার সিদ্ধান্তকে কোন মহিলা প্রভাবিত করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : রয়্যাল নেভির ব্যবহৃত বেশিরভাগ শিং এবং শণ কোথা থেকে আমদানি করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : নিউ সাউথ ওয়েলসের লেফটেন্যান্ট-গভর্নর ফ্রান্সিস গ্রোস কখন পেনাল্টি বন্দোবস্ত হিসাবে নরফোক দ্বীপটি বন্ধ করার পরামর্শ দেওয়া শুরু করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : লোকের প্রথম দল কখন নরফোক দ্বীপ ছেড়ে চলে যায়?
# The answer is :
# **************************************************
# The qusetion is : 1808 এর মধ্যে, নরফোক দ্বীপে কত লোক রয়ে গেল?
# The answer is :
# **************************************************
# The qusetion is : নিউ সাউথ ওয়েলসের গভর্নর টমাস ব্রিসবেনকে নরফোক দ্বীপে সবচেয়ে খারাপ অপরাধীদের প্রেরণের নির্দেশ দিয়েছেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে মূল ভূখণ্ডে কারা বন্দী ছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে একজন বন্দীর আটকের গড় দৈর্ঘ্য কত ছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে মানুষের পরবর্তী বসতি কোথায় থেকে এসেছিল?
# The answer is :
# **************************************************
# The qusetion is : 3 মে, 1856-তে, কত পিটকার্নার নরফোক দ্বীপে চলে গেলেন?
# The answer is :
# **************************************************
# The qusetion is : পিটকার্নাররা নরফোক দ্বীপে যে জাহাজটি ভ্রমণ করেছিল তার নাম কী?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে থাকাকালীন পিটকায়াররা কোন ব্যবসা প্রতিষ্ঠা করেছিল?
# The answer is :
# **************************************************
# The qusetion is : কমনওয়েলথ অস্ট্রেলিয়া কখন তৈরি করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন বড় ইভেন্টের সময় নরফোক দ্বীপ একটি গুরুত্বপূর্ণ এয়ারবেস এবং রিফুয়েলিং স্টেশন পরিণত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : দ্বিতীয় বিশ্বযুদ্ধের সময় নরফোক দ্বীপে ব্যবহৃত বিমানবন্দরটি কে নির্মাণ করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ দ্বিতীয় বিশ্বযুদ্ধের সময় কার দায়িত্বে পড়েছিল?
# The answer is :
# **************************************************
# The qusetion is : দ্বিতীয় বিশ্বযুদ্ধের সময় এন ফোর্স কখন নরফোক দ্বীপ ছেড়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ২০১০ সালে নরফোক দ্বীপ অস্ট্রেলিয়ার কাছে সহায়তা চেয়েছে কি?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের বাসিন্দারা অস্ট্রেলিয়ার সহায়তার ফলস্বরূপ তারা কী সুবিধা পাবে বলে জানিয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ অস্ট্রেলিয়াকে সাহায্য চাইতে বলে আসলে কী ঘটেছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের জন্য কী করার জন্য অবশেষে 12 মার্চ, 2015-এ ক্যানবেরায় একটি চুক্তি স্বাক্ষরিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ প্রশান্ত মহাসাগরের কোন অংশে অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়া সম্পর্কিত নরফোক দ্বীপ কোন দিকে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের সর্বোচ্চ পয়েন্টে পাহাড়টির নাম কী?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপপুঞ্জের দ্বিতীয় বৃহত্তম দ্বীপের নাম কী?
# The answer is :
# **************************************************
# The qusetion is : নরফোকের উপকূলরেখাটি কী দিয়ে তৈরি?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপপুঞ্জের কিংস্টনের মূল ialপনিবেশিক বন্দোবস্তের স্থানটি কোথায় অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : আমদানি করা পণ্যগুলি সাধারণত নরফোক দ্বীপে কোথায় পাঠানো হয়?
# The answer is :
# **************************************************
# The qusetion is : আপনি নরফোক দ্বীপে সার্ফ করতে কোথায় যেতে পারেন?
# The answer is :
# **************************************************
# The qusetion is : শুধুমাত্র নরফোক দ্বীপে কয়টি গাছপালা পাওয়া যায়?
# The answer is :
# **************************************************
# The qusetion is : শুধুমাত্র নরফোক দ্বীপে যে উদ্ভিদ দেখা যায় সেগুলির মধ্যে কতগুলি বিরল বা হুমকী?
# The answer is :
# **************************************************
# The qusetion is : পৃথিবীর দীর্ঘতম গাছ-পাল কোথায় পাওয়া যাবে?
# The answer is :
# **************************************************
# The qusetion is : ইউরোপীয় উপনিবেশের আগে নরফোক দ্বীপের সংখ্যাগরিষ্ঠ অংশ কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে আজ কত বৃষ্টিপাত রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের অনেক পাখি বিলুপ্ত হয়ে যাওয়ার কারণ কী?
# The answer is :
# **************************************************
# The qusetion is : কোন নর-পাখি প্রাণী নরফোক দ্বীপের পাখি জনসংখ্যার জন্য ভোগ করেছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের পাখি জনসংখ্যার জন্য কোন দেশীয় পাখি ক্ষতিগ্রস্থ হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপপুঞ্জের কোন দ্বীপে সামুদ্রিক বার্ডের প্রজননের ব্যবস্থা রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের বিলুপ্তপ্রায় পাখি কীভাবে জনসংখ্যা বৃদ্ধির লক্ষণ দেখিয়েছে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে প্রভিডেন্স পেট্রেল কোথায় প্রজনন করতে দেখা গেছে?
# The answer is :
# **************************************************
# The qusetion is : ফিলিপ দ্বীপে আর কি ধরণের পেট্রেল রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে সুটী টর্নটি কী নামে পরিচিত?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের চারপাশের জলে প্রচুর পরিমাণে ব্যবহৃত হত?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে বাণিজ্যিক সমুদ্রের শিকার কখন শুরু করেছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে কোন ধরণের তিমি এক সময় প্রচলিত ছিল, কিন্তু আজকের দিনে খুব কমই দেখা যায়?
# The answer is :
# **************************************************
# The qusetion is : খ্রিস্টানরা নরফোক দ্বীপের জনসংখ্যার কত শতাংশ রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের প্রথম চ্যাপেলেন কে?
# The answer is :
# **************************************************
# The qusetion is : রেভা জি.এইচ. এর পরে কোন ধরণের গির্জা গঠিত হয়েছিল? 1884 সালে নোবসের মৃত্যু?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের প্রথম সপ্তম দিনের অ্যাডভেন্টিস্ট গির্জার নেতৃত্ব কে দিয়েছিলেন?
# The answer is :
# **************************************************
# The qusetion is : ২০১০ সালের হিসাবে নরফোক দ্বীপে সাধারণ গির্জার জামাত কোন সংখ্যার বেশি নয়?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের বাসিন্দারা কোন ভাষায় কথা বলতে পারেন?
# The answer is :
# **************************************************
# The qusetion is : নরফুক ভাষার মিশ্রণ কী?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের সরকারী সহ-ভাষা কী?
# The answer is :
# **************************************************
# The qusetion is : ২০১০ সালের হিসাবে নরফোক দ্বীপের বাসিন্দাদের কোন অংশ নরফুক কথা বলতে পারে?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়ান একমাত্র অ-ভূখণ্ড যা নিজেই শাসিত হয়?
# The answer is :
# **************************************************
# The qusetion is : পূর্বে নরফোক দ্বীপপুঞ্জ পরিচালিত আইনটির নাম কী?
# The answer is :
# **************************************************
# The qusetion is : ২০১৫ সালে পাস হওয়া নরফোক দ্বীপ পরিচালিত নতুন আইনের নাম কী?
# The answer is :
# **************************************************
# The qusetion is : 1979-2015 চলাকালীন, আইনসভার মেয়াদ কত বছর ধরে আর স্থায়ী হয়নি?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের অ্যাসেম্বলি কতটি আসন নিয়ে গঠিত?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের জন্য নীতি নির্ধারণের জন্য দায়ী পরিষদটি কী চারটি সদস্য ছিলেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের সর্বশেষ মুখ্যমন্ত্রী কে ছিলেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে পর্যটন দায়িত্বে থাকা মন্ত্রীর সরকারী নাম কী?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়া নরফোক দ্বীপের আইনসভায় কতটি মডেল প্রস্তাব করেছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের সমাবেশকে হ্রাস করার প্রস্তাবিত পরিকল্পনাগুলির আরও তীব্র হুমকি কী হতে পারে?
# The answer is :
# **************************************************
# The qusetion is : কখন অস্ট্রেলিয়া সরকার নরফোক দ্বীপে তাদের পর্যালোচনা শেষ করে?
# The answer is :
# **************************************************
# The qusetion is : কমনওয়েলথের অস্ট্রেলিয়া কখন ঘোষণা করেছিল যে নরফোক দ্বীপটি আর নিজেরাই পরিচালিত হবে না?
# The answer is :
# **************************************************
# The qusetion is : কমনওয়েলথ নরফোক দ্বীপ সরকারকে কী দিয়ে প্রতিস্থাপন করতে চেয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : প্রস্তাবিত কাউন্সিলটি কোন রাজ্য থেকে এসেছে?
# The answer is :
# **************************************************
# The qusetion is : নতুন কাউন্সিলের ফলস্বরূপ নরফোক দ্বীপের বাসিন্দাদের কী অর্থ প্রদান শুরু করতে হবে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের আইনসভা কখন অস্ট্রেলিয়ান প্রস্তাবিত সংস্কার সম্পর্কিত ভোট দেয়?
# The answer is :
# **************************************************
# The qusetion is : ২০১ Nor সালের ৮ ই মে নরফোক দ্বীপের কতজন বাসিন্দা ভোট দিয়েছেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপপুঞ্জের শতকরা কত শতাংশ স্বশাসনের পক্ষে ভোট দিয়েছেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের মুখ্যমন্ত্রী কে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ কোন দেশের রাজ্যে পরিণত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপ কোন আইনের আওতায় অস্ট্রেলিয়ার অঞ্চল হিসাবে গৃহীত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কে 1976 সালে সিদ্ধান্ত নিয়েছিল যে নরফোক দ্বীপটি কমনওয়েলথের একটি অংশ?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে ভোটদানের জন্য প্রয়োজনীয় যোগ্যতা কী ছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে সাম্প্রতিক সময়ের মধ্যে কী ভারীভাবে সীমাবদ্ধ ছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে ইমিগ্রেশন প্রোটোকলগুলি কখন শিথিল করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে রেসিডেন্সির জন্য আবেদনের জন্য অস্ট্রেলিয়া এবং নিউজিল্যান্ডের নাগরিকদের অবশ্যই কী করতে হবে?
# The answer is :
# **************************************************
# The qusetion is : কখন অস্ট্রেলিয়ান মাইগ্রেশন সিস্টেম নরফোক দ্বীপের অভিবাসন নীতিগুলি প্রতিস্থাপন করবে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে ভ্রমণের জন্য অস্ট্রেলিয়ান নাগরিকদের কী প্রয়োজন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে ভ্রমণের জন্য অন্যান্য দেশের নাগরিকদের কী প্রয়োজন?
# The answer is :
# **************************************************
# The qusetion is : যখন কারও অস্ট্রেলিয়ান ভিসা থাকে এবং তারা নরফোক দ্বীপে ভ্রমণ করতে চায়, তাদের কোথায় যেতে হবে?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়ান ভিসা নিয়ে যাত্রী যারা অস্ট্রেলিয়ান মাইগ্রেশন অঞ্চল থেকে ছাড়েন না তাদের কী হবে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের একমাত্র মেডিকেল সেন্টারের নাম কী?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপটির দর্শনার্থীদের কেনার জন্য সুপারিশ করা হয়?
# The answer is :
# **************************************************
# The qusetion is : গুরুতর চিকিত্সা প্রয়োজন নরফোক দ্বীপ রোগীদের যেখানে করা হয়?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপে পাওয়া একটি অ্যাম্বুলেন্স কে স্টাফ করেন?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের বাসিন্দাদের বিশ্বাস কী নরফোক দ্বীপের ইইজেড লাভ থেকে প্রাপ্ত করা উচিত?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের একমাত্র প্রধান প্রাকৃতিক সম্পদ কী?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের এলাকার বাসিন্দাদের কীভাবে বিনোদনমূলকভাবে মাছ ধরার অনুমতি রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : নরফোক দ্বীপের ইইজেড জোনে কী পাওয়া যাবে বলে অনুমান করা হচ্ছে?
# The answer is :
# **************************************************
# ...
# The qusetion is : 1839 সালে ভিক্টোরিয়ার আদিবাসীদের জন্য কতটি আদিবাসী সুরক্ষক নিযুক্ত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : 240 টিরও কম ধনী ইউরোপীয় কোন পশুর লাইসেন্স ধরেছিল কোন বছরে?
# The answer is :
# **************************************************
# The qusetion is : কোন বছরের মধ্যে ভিক্টোরিয়ান আদিবাসী গোষ্ঠীগুলি তাদের জমি থেকে বহুলাংশে বাস্তুচ্যুত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নে সোনার ভিড় কখন ছিল?
# The answer is :
# **************************************************
# The qusetion is : কীভাবে মেলবোর্ন কৃষি পণ্য রফতানির জন্য প্রধান বন্দর হিসাবে বৃদ্ধি পেয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : উচ্চ শুল্ক দ্বারা কী সুরক্ষিত ছিল?
# The answer is :
# **************************************************
# The qusetion is : 1863 সালে, কেন আদিবাসী জনসংখ্যা হ্রাস পাচ্ছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন বছরে সোনার ভিড় বেশি ছিল?
# The answer is :
# **************************************************
# The qusetion is : 1860 সালের দিকে ভিক্টোরিয়ার অন্যতম প্রধান কৃষি পণ্য কোনটি ছিল?
# The answer is :
# **************************************************
# The qusetion is : বিশেষত কোন রোগের ফলে আদিবাসী জনসংখ্যা হ্রাস অব্যাহত রেখেছে?
# The answer is :
# **************************************************
# The qusetion is : আদিবাসী জনসংখ্যা 1863 দ্বারা কোন অনুমান শতাংশ দ্বারা হ্রাস পেয়েছে?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়ার ভিক্টোরিয়া রাজ্যের সর্বাধিক জনবহুল শহর কোনটি?
# The answer is :
# **************************************************
# The qusetion is : মেট্রোপলিস কোথায়?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নের বাসিন্দাদের কী বলা হয়?
# The answer is :
# **************************************************
# The qusetion is : ভিক্টোরিয়ার রাজধানী কোন শহর?
# The answer is :
# **************************************************
# The qusetion is : ভিক্টোরিয়ার সবচেয়ে জনবহুল শহর কোন শহর?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন কতটি পৌরসভা নিয়ে গঠিত?
# The answer is :
# **************************************************
# The qusetion is : ২০১৩ সালে মেলবোর্নের জনসংখ্যা কত ছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নের বাসিন্দাদের কী বলা হয়?
# The answer is :
# **************************************************
# The qusetion is : মারাত্মক হতাশা কখন মেলবোর্ন শহরে আঘাত হানে?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নে নতুন নির্মাণ কবে শুরু হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়ায় কখন ব্যাংকিংয়ের সংকট ছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন দশকে মেলবোর্ন মারাত্মক অর্থনৈতিক মানসিক চাপে পড়েছিলেন?
# The answer is :
# **************************************************
# The qusetion is : 1890-এর দশকে মেলবোর্নে হতাশার সময় কতগুলি "স্থল ব্যাংক" এবং বিল্ডিং সোসাইটি ভেঙে পড়ে?
# The answer is :
# **************************************************
# The qusetion is : 1890 এর দশকে মেলবোর্নে হতাশার সময় কতগুলি সীমাবদ্ধ সংস্থাগুলি তরলবলে যায়?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন আর্থিক সংকট 1893 সালে কোন ব্যাংকিং সংকট একটি অবদান কারণ ছিল?
# The answer is :
# **************************************************
# The qusetion is : ১৮৯০ এর দশকের গোড়ার দিকে মেলবোর্নে হতাশার পরে নতুন নির্মাণ কবে নতুনভাবে শুরু হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ইয়ারার দক্ষিণ তীরে প্রতিষ্ঠিত বস্তিগুলিকে কোন পদ দেওয়া হয়?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন চিনাটাউন কোন সালে প্রতিষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন নৃগোষ্ঠী আন্তঃদেশীয় এবং বিদেশী অভিবাসীদের মেলবোর্নে আগমনকে অবদান রেখেছিল?
# The answer is :
# **************************************************
# The qusetion is : পশ্চিমা বিশ্বের দীর্ঘতম নিরবচ্ছিন্ন চীনা বসতি কোন সম্প্রদায়ের?
# The answer is :
# **************************************************
# The qusetion is : কোন শতাব্দীর দ্বিতীয়ার্ধে বার্ক এবং উইলস অভিযান অভিবাসন প্রবাহের ইঙ্গিত দিয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নে কোন টেলিফোন এক্সচেঞ্জ প্রতিষ্ঠিত হয়?
# The answer is :
# **************************************************
# The qusetion is : পূর্ব মার্কেটে প্রথম বৈদ্যুতিক আলো কখন ইনস্টল করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন তারের ট্রামওয়ে সিস্টেমের প্রথম লাইনটি কোন সালে নির্মিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : 1880 সালের মেলবোর্ন আন্তর্জাতিক প্রদর্শনীটি কোন ভবনে অনুষ্ঠিত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নের রেকর্ডের সর্বনিম্ন তাপমাত্রাটি কোন তারিখে হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়ার দীর্ঘতম টাওয়ারটি কী?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নের দ্বিতীয় লম্বা কোন টাওয়ার?
# The answer is :
# **************************************************
# The qusetion is : রিয়াল্তোর পর্যবেক্ষণ ডেক বর্তমানে চালু বা বন্ধ আছে?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নের কোন তীরে ইউরেকা টাওয়ার অবস্থিত?
# The answer is :
# **************************************************
# The qusetion is : পুরানো সিবিডির সবচেয়ে উঁচু বিল্ডিং কোন বিল্ডিং?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন কোন অঞ্চলে উল্লেখযোগ্য আন্তর্জাতিক বিনিয়োগ উত্সর্গ করেছে?
# The answer is :
# **************************************************
# The qusetion is : শহরগুলির অভ্যন্তরীণ নগরীর পুনর্নবীকরণ কোন অঞ্চলে ঘটেছে?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন কত সালে সর্বোচ্চ জনসংখ্যা বৃদ্ধি এবং অর্থনৈতিক বৃদ্ধি বজায় রেখেছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নে আবাসনগুলির জন্য উচ্চ চাহিদা কী উত্পাদন করছে?
# The answer is :
# **************************************************
# The qusetion is : হাউজিং বুম বাড়ির দাম এবং ভাড়া নিয়ে কী প্রভাব ফেলেছে?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নের কোন শহরতলিতে সাম্প্রতিক বছরগুলিতে উল্লেখযোগ্য ব্রাউনফিল্ডগুলির পুনর্নবীকরণ দেখা গেছে?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন নীতিগুলি কোন ধরণের শহরতলির উন্নয়নের প্রচার করেছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন কে সম্মানের জন্য নামকরণ করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্ন কোন বছর সরকারীভাবে একটি শহর ঘোষণা করা হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন বছরে মেলবোর্ন দেশগুলির অন্তর্বর্তীকালীন সরকার হিসাবে কাজ করা বন্ধ করে দিয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : 1851 সালে মেলবোর্ন কোন উপনিবেশের রাজধানী হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন বছরে মেলবোর্ন কার্বন নিঃসরণকে নেট শূন্যে হ্রাস করার লক্ষ্য নির্ধারণ করেছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন বছর মেলবোর্ন সম্পূর্ণরূপে কার্বন নিরপেক্ষ হওয়ার ইচ্ছা প্রকাশ করেছিল?
# The answer is :
# **************************************************
# The qusetion is : কোন শহরটি ২০০৯ সালে উল্লেখযোগ্যভাবে কার্বন নিরপেক্ষ হয়ে উঠেনি?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নের কি বিশ্বের বৃহত্তম বা ক্ষুদ্রতম কার্বন পদচিহ্ন রয়েছে?
# The answer is :
# **************************************************
# The qusetion is : মেলবোর্নে দূষণ নিয়ন্ত্রণে দায়িত্বে কে?
# The answer is :
# **************************************************
# The qusetion is : 1889 সালে রিয়াল্টো বিল্ডিং কে ডিজাইন করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : 1890 সালে উইনফিল্ড বিল্ডিং কে ডিজাইন করেছিলেন?
# The answer is :
# **************************************************
# The qusetion is : ২০১৪ সালের জানুয়ারিতে কোন ভবনটি বিশ্বের ১৩ তমতম আবাসিক ভবন হিসাবে তালিকাভুক্ত হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : ইউরেকা টাওয়ারটি কোন বছরে শেষ হয়েছিল?
# The answer is :
# **************************************************
# The qusetion is : অস্ট্রেলিয়ার অন্যান্য স্কাইলাইনের ক্ষেত্রে মেলবোর্নের আকাশ লাইনের অবস্থান কীভাবে?
# The answer is :
# **************************************************
# The qusetion is : তাসমানিয়া আগে কি নামে পরিচিত ছিল?
# The answer is :
# **************************************************
# The qusetion is : বর্তমান মধ্য এবং উত্তর মেলবোর্ন কার দ্বারা অনুসন্ধান করা হয়েছিল?
# The answer is :
# **************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-aeb3ecebf342> in <module>()
#       2     val_encodings=tokenizer(contxt, quas, truncation=True, padding=True)
#       3     with torch.no_grad():
# ----> 4          outputs = model(input_ids, attention_mask=attention_mask)
#       5          start_pred = torch.argmax(outputs['start_logits'], dim=1)
#       6          end_pred = torch.argmax(outputs['end_logits'], dim=1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1782             output_attentions=output_attentions,
#    1783             output_hidden_states=output_hidden_states,
# -> 1784             return_dict=return_dict,
#    1785         )
#    1786
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     979             output_attentions=output_attentions,
#     980             output_hidden_states=output_hidden_states,
# --> 981             return_dict=return_dict,
#     982         )
#     983         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     573                     encoder_attention_mask,
#     574                     past_key_value,
# --> 575                     output_attentions,
#     576                 )
#     577
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     459             head_mask,
#     460             output_attentions=output_attentions,
# --> 461             past_key_value=self_attn_past_key_value,
#     462         )
#     463         attention_output = self_attention_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     394             output_attentions,
#     395         )
# --> 396         attention_output = self.output(self_outputs[0], hidden_states)
#     397         outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     398         return outputs
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, input_tensor)
#     346         hidden_states = self.dense(hidden_states)
#     347         hidden_states = self.dropout(hidden_states)
# --> 348         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#     349         return hidden_states
#     350
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/normalization.py in forward(self, input)
#     169     def forward(self, input: Tensor) -> Tensor:
#     170         return F.layer_norm(
# --> 171             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     172
#     173     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2203             layer_norm, (input,), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2204         )
# -> 2205     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2206
#    2207
#
# KeyboardInterrupt:
